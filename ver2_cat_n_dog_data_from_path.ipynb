# %% [markdown]
# <a href="https://colab.research.google.com/github/drawcodeboy/Cat_n_Dog_Classification/blob/main/ver2_cat_n_dog_data_from_path.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image

# %%
train_path = '/content/drive/MyDrive/cat_n_dog/training_set/training_set'
test_path = '/content/drive/MyDrive/cat_n_dog/test_set/test_set'

# %%
train_list = []
train_target = []

for dirname, _, filenames in os.walk(train_path):
    for filename in filenames:
        if(filename.endswith('jpg')):
            if(filename[0] == 'c'):
                train_target.append(0)
            elif(filename[0] == 'd'):
                train_target.append(1)
            train_count = os.path.join(dirname, filename)
            train_list.append(train_count)

# %%
test_list = []
test_target = []

for dirname, _, filenames in os.walk(test_path):
    for filename in filenames:
        if(filename.endswith('jpg')):
            if(filename[0] == 'c'):
                test_target.append(0)
            elif(filename[0] == 'd'):
                test_target.append(1)
            test_count = os.path.join(dirname, filename)
            test_list.append(test_count)

# %%
from tensorflow.keras.preprocessing import image

train_set = []

for i, f in enumerate(train_list):
    img = image.load_img(f)
    img_np = np.array(img)
    train_set.append(img_np)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-171fe4196b34> in <module>
#       4
#       5 for i, f in enumerate(train_list):
# ----> 6     img = image.load_img(f)
#       7     img_np = np.array(img)
#       8     train_set.append(img_np)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     391     if isinstance(path, pathlib.Path):
#     392       path = str(path.resolve())
# --> 393     with open(path, 'rb') as f:
#     394       img = pil_image.open(io.BytesIO(f.read()))
#     395   else:
#
# KeyboardInterrupt:

# %%
test_set = []

for i, f in enumerate(test_list):
    img = image.load_img(f)
    img_np = np.array(img)
    test_set.append(img_np)

# %%
"""
train_set_np = np.array(train_set)
test_set_np = np.array(test_set)
train_target_np = np.array(train_target)
test_target_np = np.array(test_target)

np.save('/content/drive/MyDrive/cat_n_dog/data_numpy/train_set', train_set_np)
np.save('/content/drive/MyDrive/cat_n_dog/data_numpy/test_set', test_set_np)
np.save('/content/drive/MyDrive/cat_n_dog/data_numpy/train_target', train_target_np)
np.save('/content/drive/MyDrive/cat_n_dog/data_numpy/test_target', test_target_np)
"""
